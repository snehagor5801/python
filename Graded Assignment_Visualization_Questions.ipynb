# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the dataset
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### 1.Create a Line Plot with x (‘total_bill’) versus y (‘tip’) using lineplot() function:

# %%
sns.lineplot(x="total_bill", y="tip", data=df)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Line Plot of Total Bill vs. Tip")
plt.show()

# %% [markdown]
# #### 2.Create a scatter plot with total_bill and tip

# %%
sns.scatterplot(x="total_bill", y="tip", data=df)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Scatter Plot of Total Bill vs. Tip")
plt.show()

# %% [markdown]
# #### 3.Write a python code to create a hist plot on total_bill with bins=10.
# - Create the following
# -Title as "Frequency of Bill Amount"
# -xlabel as "Billed Amount"
# -ylabel as "Count"

# %%
sns.histplot(data=df, x="total_bill", bins=10, kde=False, color="pink")
plt.title("Frequency of Bill Amount")
plt.xlabel("Billed Amount")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### 4.Write a python code to create a heatmap on tips dataset by showing the corelation between numeric attributes

# %%
df.corr()
# Out:
# C:\Users\Sneha Mayur Gor\AppData\Local\Temp\ipykernel_25044\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(7,4)) 
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Heatmap of Numeric Attributes")
plt.show()
# Out:
# C:\Users\Sneha Mayur Gor\AppData\Local\Temp\ipykernel_25044\3575226629.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# #### 5.Write a python code to create a barplot on smoker and total_bill attribute

# %%
plt.figure(figsize=(7,4))
sns.barplot(x="smoker", y="total_bill", data=df)
plt.xlabel("Smoker")
plt.ylabel("Total Bill")
plt.title("Bar Plot of Total Bill by Smoker")
plt.show()

# %% [markdown]
# #### 6.Write a python code to use the countplot() function to show the count of smokers and non-smokers:

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="smoker", data=df)
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.title("Count of Smokers and Non-Smokers")
plt.show()

# %% [markdown]
# #### 7.Let’s write a python code to analyze how the tipped amount varies during lunch and dinner time and if there are any outliers in our data. Hint :(Boxplot)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="time", y="tip", data=df)
plt.xlabel("Time")
plt.ylabel("Tip Amount")
plt.title("Boxplot of Tip Amount by Time (Lunch vs. Dinner)")
plt.show()

# %% [markdown]
# #### 8.Let’s write a python code to create a pair plot to show the pair wise distribution of all attributes

# %%
sns.pairplot(data=df, hue="time")
plt.show()

# %% [markdown]
# **********************************THE END*************************
